# %% [markdown]
# #  Statistics Advance Part 1 - Assignment

# %% [markdown]
# Que1. What is a random variable in probability theory ?
#
# Ans: In probability theory, a random variable is a function that assigns a numerical value to each outcome in a sample space, effectively quantifying the uncertainty inherent in random phenomena. It bridges the gap between real-world experiments and mathematical analysis, allowing us to model and analyze uncertain events.v

# %% [markdown]
# Que2. What are the types of random variables ?
#
# Ans:Types of Random Variables are as follws
#
# 1) Discrete Random Variables :
#
# These take on a finite or countably infinite number of distinct values. Examples include:
#
# The number of heads in a series of coin tosses.
#
# The number of customers arriving at a store in an hour.
#
# Discrete random variables are analyzed using a probability mass function (PMF), which assigns probabilities to each possible value. The sum of all probabilities must equal 1.
#
# 2) Continuous Random Variables :
#
# These can take on an infinite number of values within a given range. Examples include:
#
# The height of individuals,The weight of employees
# ,The amount of rainfall in a region.
#
# Continuous random variables are described by a probability density function (PDF). The probability that the variable falls within a particular range is found by integrating the PDF over that range.

# %% [markdown]
# Que3. What is the difference between discrete and continuous distributions ?
#
# Ans: A) Discrete Probability Distributions
#
# 1) Nature: Deal with random variables that take on a finite or countably infinite number of distinct values.
#
# 2) Examples:
#
# Number of heads in 10 coin flips.
#
# Count of customers arriving at a store in an hour.
#
# Number of defective items in a batch.
#
# 3) Probability Assignment: Each specific outcome has a non-zero probability.
#
# 4) Graphical Representation: Often depicted using bar charts or histograms.
#
# 5) Key Distributions:
#
# Binomial Distribution
#
# Poisson Distribution
#
# Geometric Distribution
#
# Bernoulli Distribution
#
#
# B)  Continuous Probability Distributions
#
# 1) Nature: Concern random variables that can assume any value within a given interval, typically an infinite number of possibilities.
#
# 2) Examples:
#
# Height of individuals.
#
# Time taken to run a race.
#
# Amount of rainfall in a region.
#
# 3) Probability Assignment: The probability of any exact value is zero; probabilities are assigned over intervals.
#
# 4) Graphical Representation: Represented by smooth curves, such as probability density functions (PDFs).
#
# 5) Key Distributions:
#
# Normal Distribution
#
# Exponential Distribution
#
# Uniform Distribution
#
# Gamma Distribution

# %% [markdown]
# Que4. What are probability distribution functions (PDF) ?
#
# Ans: Types of Probability Distribution Functions :
#
# A) Discrete Probability Distribution Function
#
# 1) Definition: Used for random variables that take on a finite or countably infinite number of distinct values.
#
# 2) Key Characteristics:
#
# a) Each probability is between 0 and 1.
#
# b) The sum of all probabilities equals 1.
#
# 3) Example: The number of heads in 10 coin flips.
#
#
# 4) Common Distributions:
#
# a) Binomial Distribution: Models the number of successes in a fixed number of independent Bernoulli trials.
#
# b) Poisson Distribution: Describes the number of events occurring in a fixed interval of time or space.
#
# c) Geometric Distribution: Models the number of trials until the first success.
#
#
# B) Continuous Probability Distribution Function
#
# 1) Definition: Used for random variables that can take on any value within a given range.
#
# 2) Key Characteristics:
#
# 3) The probability of any exact value is zero; probabilities are assigned over intervals.
#
# 4) The total area under the curve equals 1.
#
# 5) Example: The height of individuals in a population.
#
# 6) Common Distributions:
#
# a) Normal Distribution: Characterized by its bell-shaped curve, defined by its mean and standard deviation.
#
# b) Exponential Distribution: Models the time between events in a Poisson process.
#
# c) Uniform Distribution: All outcomes are equally likely within a certain range.

# %% [markdown]
# Que5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF).
#
# Ans: Probability Density Function (PDF):
#
# 1) Definition:
#
# Continuous Random Variables: A PDF, denoted as
# 𝑓
# 𝑋
# (
# 𝑥
# )
# f
# X
# ​
#  (x), describes the likelihood of a continuous random variable
# 𝑋
# X taking on a specific value. For continuous variables, the probability of any exact value is zero; instead, the PDF indicates the probability density.
#
# 2) Key Properties
# Non-Negativity:
# 𝑓
# 𝑋
# (
# 𝑥
# )
# ≥
# 0
# f
# X
# ​
#  (x)≥0 for all
# 𝑥
# x.
#
# Normalization: The total area under the PDF curve equals 1:
#
# 3) Probability Calculation: The probability that
#
# X lies within an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is the area under the curve between
# 𝑎
# a and
# 𝑏
# b:
#
# Example
# Uniform Distribution: For a uniform distribution over the interval [0, 1], the PDF is constant, indicating that every value within this range is equally likely.
#
# 2) Cumulative Distribution Function (CDF) :
#
# Definition
# The CDF, denoted as
# 𝐹
# 𝑋
# (
# 𝑥
# )
# F
# X
# ​
#  (x), gives the probability that the random variable
#
# X takes a value less than or equal to
# 𝑥
#
# 3)Key Properties
#
# a) Monotonicity:
# 𝐹
# 𝑋
# (
# 𝑥
# )
# F
# X
# ​
#  (x) is non-decreasing.
#
# b) Continuity:
# 𝐹
# 𝑋
# (
# 𝑥
# )
# F
# X
# ​
#  (x) is right-continuous.
#
# 3) Example
# Uniform Distribution: For a uniform distribution over the interval [0, 1], the CDF increases linearly from 0 to 1 as
# 𝑥
# x moves from 0 to 1.

# %% [markdown]
# Que6. What is a discrete uniform distribution ?
#
# Ans: A Discrete Uniform Distribution is a type of probability distribution where a finite set of distinct outcomes are equally likely to occur. This means each outcome within the set has the same probability of happening.
#
# Defination : A discrete random variable
# X follows a discrete uniform distribution over a set of
# n equally likely outcomes if its probability mass function (PMF) is:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 𝑛
# ,
# for
# 𝑥
# ∈
# {
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# …
# ,
# 𝑥
# 𝑛
# }
# P(X=x)=
# n
# 1
# ​
#  ,for x∈{x
# 1
# ​
#  ,x
# 2
# ​
#  ,…,x
# n
# ​
#  }
#
# Key Properties
#
# 1) Equal Probability: Each outcome has an equal chance of occurring.
#
# 2) Finite Outcomes: The set of possible outcomes is finite and countable.
#
# 3) Constant PMF: The probability mass function is constant over the range of possible outcomes.

# %% [markdown]
# Que7. What are the key properties of a Bernoulli distribution ?
#
# Ans: Key Properties of the Bernoulli Distribution
# Binary Outcomes
# The distribution models experiments with two outcomes: success (1) and failure (0).
#
# 1) Constant Probability :
#
# The probability of success, denoted as
# 𝑝
# p, remains constant across trials. The probability of failure is
# 𝑞
# =
# 1
# −
# 𝑝
#
#
# 2) Discrete Distribution :
#
# The Bernoulli distribution is discrete, as it involves a finite number of outcomes (0 and 1).
#
# 3) Probability Mass Function (PMF) :
#
# The PMF of a Bernoulli random variable
# X is:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# 𝑥
# (
# 1
# −
# 𝑝
# )
# 1
# −
# 𝑥
# ,
# for
# 𝑥
# ∈
# {
# 0
# ,
# 1
# }
#
# This function assigns probabilities to the two possible outcomes.
#
# 4) Expected Value (Mean) :
#
# The expected value of a Bernoulli random variable
# X is:
#
# 𝐸
# [
# 𝑋
# ]
# =
# 𝑝
#
# This represents the average outcome over many trials.
#
# 5) Variance
#
# The variance of X is:
#
# Var(X)=p(1−p)
# This measures the spread of the distribution around the mean.
#
# 6) Moment-Generating Function (MGF)
#
# The MGF of X is:
#
# M
# X
# ​
#  (t)=q+pe
# t
#
# This function is useful for deriving moments and analyzing the distribution's properties.
#
# 7) Skewness
#
# The skewness of
# X is:
#
# 𝛾
# 1
# =
# 1
# −
# 2
# 𝑝
# 𝑝
# (
# 1
# −
# 𝑝
# )
# γ
# 1
# ​
#  =
# p(1−p)
# ​
#
# 1−2p
# ​
#
# This indicates the asymmetry of the distribution.
#
# 7) Kurtosis
#
# The excess kurtosis of
# X is:
#
# 𝜅
# 2
# =
# 1
# −
# 6
# 𝑝
# (
# 1
# −
# 𝑝
# )
# 𝑝
# (
# 1
# −
# 𝑝
# )
#
# This measures the "tailedness" of the distribution.
#
# Maximum Likelihood Estimator (MLE)
# The MLE for
# p, based on a sample of Bernoulli trials, is the sample mean:
#
# 𝑝
# ^
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑋
# 𝑖
# p
# ^
# ​
#  =
# n
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  X
# i
# ​
#
# This estimator is unbiased and efficient.

# %% [markdown]
# Que8. What is the binomial distribution, and how is it used in probability ?
#
# Ans: The binomial distribution is a fundamental concept in probability theory and statistics, describing the number of successes in a fixed number of independent experiments, each with two possible outcomes: success or failure. These experiments are known as Bernoulli trials.
#
# A binomial distribution is characterized by:
#
# Number of trials (n): The total number of independent experiments.
#
# Probability of success (p): The probability of a success on a single trial.
#
# Probability of failure (q): Calculated as
# 𝑞
# =
# 1
# −
# 𝑝
#
#
# Number of successes (k): The number of successful outcomes in the trials.
#
# * How Is It Used in Probability:
#
# The binomial distribution is widely applied in various fields to model scenarios with two possible outcomes. Here are some practical examples:
#
# Coin Tossing: Determining the probability of getting a certain number of heads in a fixed number of coin flips.
#
# Quality Control: Assessing the probability of a certain number of defective items in a batch of products.
#
# Medical Studies: Estimating the probability of a certain number of patients responding to a treatment.

# %% [markdown]
# Que9. What is the Poisson distribution and where is it applied ?
#
# Ans: The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events happen independently and at a constant average rate. It is particularly useful for modeling rare or infrequent events.
#
# Real-World Applications :
#
# The Poisson distribution is widely utilized in various fields, particularly in scenarios where events occur sporadically and independently. Some common applications include:
# DataForest
#
# 1) Call Centers: Modeling the number of incoming calls per minute or hour to optimize staffing levels and reduce wait times.
#
# 2) Traffic Flow Analysis: Estimating the number of vehicles passing through a toll booth or intersection during a specific time period.
#
# 3) Healthcare and Hospital Management: Predicting the number of patients arriving at an emergency department within a given time frame to ensure adequate staffing and resources.
#
# 4) Quality Control in Manufacturing: Modeling the number of defects or failures in a production process to assess product quality and identify areas for improvement.
#
# 5) Natural Disaster Occurrences: Estimating the number of rare events, such as earthquakes or meteor showers, within a specified period.

# %% [markdown]
# Que10.What is a continuous uniform distribution ?
#
# Ans: A continuous uniform distribution is a probability distribution where all outcomes are equally likely within a specified interval [a,b]. This means that any value within this range has the same probability of occurring.
#
# The probability density function (PDF) of a continuous uniform distribution is defined as:
#
# f(x) = 1/b-a for a<=x<=b
#
# Outside this interval, the probability density is zero. This results in a rectangular shape when plotted, hence the name "rectangular distribution" .

# %% [markdown]
# Que11. What are the characteristics of a normal distribution ?
#
# Ans: Key Characteristics of a Normal Distribution
#
# 1) Symmetry:
# The distribution is perfectly symmetric around its mean. This means the left and right sides of the curve are mirror images of each other.
#
# 2) Bell-Shaped Curve:
# The graph of a normal distribution is bell-shaped, with the highest point at the mean, and it tapers off equally on both sides.
#
# 3) Mean, Median, and Mode Equality:
# In a normal distribution, the mean (average), median (middle value), and mode (most frequent value) are all equal and located at the center of the distribution.
#
# 4) Empirical Rule (68-95-99.7 Rule):
# This rule states that:
#
# Approximately 68% of the data falls within one standard deviation of the mean.
#
# Approximately 95% falls within two standard deviations.
#
# Approximately 99.7% falls within three standard deviations.
# This illustrates how data is concentrated around the mean.
#
# 5) Asymptotic Nature:
# The tails of the normal distribution curve approach, but never touch, the horizontal axis. This means that extreme values are possible, but their probability of occurrence is virtually zero.
#
# 6) Defined by Two Parameters:
#
# a) Mean (μ): Determines the center of the distribution.
#
# b) Standard Deviation (σ): Measures the spread or dispersion of the data. A larger standard deviation indicates a wider spread.
#
# c) Total Area Under the Curve Equals One:
# The total area under the normal distribution curve is equal to 1, representing the total probability of all outcomes.

# %% [markdown]
# Que12. What is the standard normal distribution, and why is it important ?
#
# Ans: The standard normal distribution is a special case of the normal distribution with the following characteristics:
#
# Mean (μ) = 0
#
# Standard Deviation (σ) = 1
#
# * Importance of the Standard Normal Distribution :
#
# 1) Standardization of Data: The standard normal distribution allows for the conversion of any normal distribution to a standard form using Z-scores. A Z-score represents the number of standard deviations a data point is from the mean, facilitating comparisons across different datasets.
#
#
# 2) Central Limit Theorem (CLT): The CLT states that the distribution of sample means approaches a standard normal distribution as the sample size increases, regardless of the original data distribution. This underpins many statistical methods and justifies the use of the standard normal distribution in inferential statistics.
#
#
# 3) Statistical Inference: Many statistical tests, such as Z-tests and t-tests, assume normality in data. The standard normal distribution provides a basis for these tests, enabling the calculation of probabilities and critical values.
#
# 4) Quality Control: In manufacturing, the standard normal distribution is used to monitor and maintain product quality. By analyzing deviations from the mean, companies can identify and address variations in production processes.

# %% [markdown]
# Que13. What is the Central Limit Theorem (CLT), and why is it critical in statistics ?
#
# Ans : 1) Sampling Distribution of the Mean: When you take multiple random samples from a population and compute their means, the distribution of these sample means will tend to be normal as the sample size grows, even if the population distribution is not normal.
#
# 2) Sample Size Consideration: A sample size of 30 or more is generally considered sufficient for the CLT to hold, making the sampling distribution approximately normal.
#
#
# 3) Mean and Standard Deviation:
#
# a) Mean of the Sampling Distribution: The mean of the sample means will be equal to the population mean (μ).
#
# b) Standard Deviation (Standard Error): The standard deviation of the sample means, known as the standard error, is equal to the population standard deviation (σ) divided by the square root of the sample size (n):
#
# Standard Error
# =
# 𝜎/√n
#
#
# * Why the CLT is Critical in Statistics :
#
# 1) Foundation for Statistical Inference: The CLT justifies the use of normal probability models for inference, even when the underlying data are not normally distributed. This is essential for constructing confidence intervals and conducting hypothesis tests.
#
# 2) Simplifies Analysis: It allows statisticians to apply normal distribution techniques to a wide range of problems, facilitating easier analysis and interpretation of data.
#
# 3) Predictive Power: By ensuring that sample means are normally distributed, the CLT enables more accurate predictions and decisions based on sample data.

# %% [markdown]
# Que14. How does the Central Limit Theorem relate to the normal distribution ?
#
# Ans: How the CLT Relates to the Normal Distribution :
#
# 1) Sampling Distribution of the Mean: When you take multiple random samples from a population and compute their means, the distribution of these sample means will tend to be normal as the sample size grows, even if the population distribution is not normal.
#
# 2) Sample Size Consideration: A sample size of 30 or more is generally considered sufficient for the CLT to hold, making the sampling distribution approximately normal.
# Scribbr
#
# 3) Mean and Standard Deviation:
#
# Mean of the Sampling Distribution: The mean of the sample means will be equal to the population mean (μ).
#
# Standard Deviation (Standard Error): The standard deviation of the sample means, known as the standard error, is equal to the population standard deviation (σ) divided by the square root of the sample size (n):

# %% [markdown]
# Que15. What is the application of Z statistics in hypothesis testing ?
#
# Ans:  Applications of the Z-Test :
#
# 1) Quality Control: Manufacturers use Z-tests to ensure that products meet specified standards. For example, testing if the average weight of a batch of products deviates from the target weight.
#
# 2) Medical Research: In clinical trials, Z-tests help compare the effectiveness of treatments. For instance, determining if the mean recovery time differs between two groups of patients.
# Canonica
#
# 3) Finance: Investors use Z-tests to assess the performance of investment portfolios by comparing sample means to expected returns.

# %% [markdown]
# Que 16. How do you calculate a Z-score, and what does it represent ?
#
# Ans:A Z-score (also known as a standard score) quantifies how many standard deviations a specific data point (raw score) is away from the mean of its dataset. This standardization allows for comparison across different datasets, even if they have different units or scales.
#
# The formula for calculating a Z-score is:
#
# ![image.png](data:image/png;base64,...)
#
# Where:
#
#
# X = the raw score (data point)
#
#
# μ = the mean of the population
#
#
# σ = the standard deviation of the population
#
# What Does a Z-Score Represent?
#
# 1) Positive Z-score: The data point is above the mean. For example, a Z-score of +2 indicates the value is 2 standard deviations above the mean.
# Simply Psychology
#
# 2) Negative Z-score: The data point is below the mean. A Z-score of -1.5 means the value is 1.5 standard deviations below the mean.
#
# 3) Z-score of 0: The data point is exactly at the mean.

# %% [markdown]
# Que17. What are point estimates and interval estimates in statistics ?
#
# Ans: 1) Point Estimate :
#
# A point estimate is a single numerical value derived from sample data, serving as the best guess for an unknown population parameter. For example:
#
# The sample mean (average) is a point estimate for the population mean.
#
# The sample proportion is a point estimate for the population proportion.
#
#
# While point estimates are straightforward to compute and interpret, they do not convey any information about the uncertainty or variability associated with the estimate. This means that the true population parameter could differ from the point estimate due to sampling variability.
# Fiveable
#
# 2) Interval Estimate
# An interval estimate provides a range of values within which the population parameter is expected to lie, accompanied by a specified level of confidence. The most common form of interval estimate is the confidence interval.
#
# For instance, a 95% confidence interval for a population mean might be expressed as:
#
# "We are 95% confident that the true population mean lies between 2.5 and 3.5."
#
#
# This means that if we were to take 100 different samples and compute a confidence interval from each, approximately 95 of those intervals would contain the true population mean.
# Wikipedia
#
# Interval estimates offer more comprehensive information by quantifying the uncertainty inherent in sample-based estimates. They are particularly useful when making decisions or inferences that require an understanding of the potential variability in the data.

# %% [markdown]
# Que18. What is the significance of confidence intervals in statistical analysis ?
#
# Ans: Significance of Confidence Intervals :
# 1. Quantifying Uncertainty
# CIs communicate the degree of uncertainty around an estimate. For example, a 95% CI suggests that if the same sampling procedure were repeated numerous times, approximately 95% of the calculated intervals would contain the true population parameter. This helps researchers understand the reliability of their estimates.
# PubMed Central
#
# 2. Assessing Statistical Significance
# CIs can indicate statistical significance by checking if they include a value representing "no effect." For instance, in comparing two groups, if the CI for the difference in means does not include zero, it suggests a statistically significant difference at the chosen confidence level.
# The Medical Journal of Australia
#
#
# 3. Evaluating Practical Significance
# Beyond statistical significance, CIs provide insight into the practical or clinical significance of results. A narrow CI indicates a precise estimate, while a wide CI suggests greater uncertainty. This is particularly important in fields like medicine, where decisions can have significant consequences.
#
#
# 4. Comparing Studies
# When comparing results across different studies, CIs allow researchers to assess the consistency of findings. Studies with overlapping CIs suggest similar results, whereas non-overlapping CIs may indicate differing conclusions. This is valuable in meta-analyses and systematic reviews.
#
# 5. Guiding Decision-Making
# In applied settings, such as healthcare policy or business strategy, CIs inform decision-making by providing a range of possible outcomes. This enables stakeholders to make informed choices that consider both the potential benefits and risks.

# %% [markdown]
# Que19.  What is the relationship between a Z-score and a confidence interval ?
#
# Ans: The Z-score plays a pivotal role in constructing confidence intervals (CIs) in statistics. It serves as a critical value that determines the range within which a population parameter is estimated to lie, based on sample data.
#
# Relationship Between Z-Scores and Confidence Intervals :
#
# The Z-score is integral to constructing confidence intervals. It determines the margin of error, which, when added to and subtracted from the sample mean, yields the confidence interval. The Z-score corresponds to the desired confidence level and is derived from the standard normal distribution.

# %% [markdown]
# Que20. How are Z-scores used to compare different distributions ?
#
# Ans:  Comparing Different Distributions Using Z-Scores
# When comparing data points from different distributions, Z-scores offer several advantages:
#
# 1. Standardization Across Units and Scales :
#
# Different datasets may have different units (e.g., height in centimeters vs. weight in kilograms) and scales. Z-scores eliminate these discrepancies by converting raw scores into a common scale. For instance, if one dataset has a mean of 100 and a standard deviation of 15, and another has a mean of 50 and a standard deviation of 5, a raw score of 120 in both datasets would correspond to Z-scores of 1.33 and 1.40, respectively. This standardization allows for meaningful comparisons between the two datasets.
#
# 2. Identifying Relative Positions :
#
# Z-scores indicate how a data point compares to the rest of the data in its distribution. A Z-score of 2 means the data point is two standard deviations above the mean. By comparing Z-scores, one can determine which data point is relatively higher or lower, regardless of the original scales.
#
# 3. Assessing Probabilities and Percentiles :
#
# Z-scores correspond to specific percentiles in a standard normal distribution. For example, a Z-score of 1.96 corresponds to the 97.5th percentile, meaning 97.5% of the data lies below this value. This relationship allows for probabilistic comparisons between different datasets.
#
# 4. Detecting Outliers :
#
# Data points with Z-scores beyond a certain threshold (commonly ±2 or ±3) are considered outliers. By calculating Z-scores, one can identify and compare outliers across different datasets.
#
# Practical Example: Comparing Exam Scores
# Consider two students, Alice and Bob, who took different exams:
#
# Alice: Scored 85 on an exam with a mean of 80 and a standard deviation of 5.
#
# Bob: Scored 90 on an exam with a mean of 85 and a standard deviation of 10.

# %% [markdown]
# Que21. What are the assumptions for applying the Central Limit Theorem ?
#
# Ans: Assumptions for the Central Limit Theorem
# 1) Random Sampling :
#
# Samples must be randomly selected from the population to ensure that every individual has an equal chance of being included. This randomness helps in obtaining a representative sample, minimizing bias.
#
# 2)Independence :
#
# Each sample must be independent of the others. This means the selection or outcome of one sample should not influence another. For example, when sampling without replacement, the sample size should be less than 10% of the total population to maintain independence.
#
# 3) Sample Size :
#
# A sufficiently large sample size is crucial. While there's no strict rule, a common guideline is that a sample size of 30 or more is adequate for the CLT to hold. However, if the population distribution is highly skewed or has heavy tails, a larger sample size may be necessary.
#
# 4) Finite Mean and Variance :
#
# The population from which samples are drawn should have a finite mean and variance. Distributions with infinite variance, like the Cauchy distribution, do not satisfy this condition, and the CLT may not apply.

# %% [markdown]
# Que22. What is the concept of expected value in a probability distribution ?
#
# Ans: The expected value (often denoted as
# 𝐸
# [
# 𝑋
# ]
# or
# μ) of a probability distribution is a fundamental concept in statistics and probability theory. It represents the long-term average or mean of a random variable over numerous trials or observations. In essence, the expected value provides a measure of the center of the distribution, indicating where the values are likely to cluster.

# %% [markdown]
# Que23. How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans: The expected value (denoted as
# 𝐸
# [
# 𝑋
# ] or
# μ) of a random variable is a fundamental concept in probability theory and statistics. It represents the long-term average or mean of the outcomes of a random variable over numerous trials or observations. This measure provides insight into the center or "balance point" of a probability distribution.
#
# ![image.png](data:image/png;base64,...)
